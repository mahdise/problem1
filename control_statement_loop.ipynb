# %%
i =1
num1=3
num2=5

while i<=100:
        
    if i%num1==0 and i%num2==0:
        print("Mahdi Nazmul")
        
    elif i%num1==0 and i%num2 !=0:
        print("Mahdi")
        
    elif i%num2==0 and i%num1 !=0:
        print("Nazmul")
        
    else:
        print(i)
        
        
    i+=1
# Out:
# 1
# 2
# Mahdi
# 4
# Nazmul
# Mahdi
# 7
# 8
# Mahdi
# Nazmul
# 11
# Mahdi
# 13
# 14
# Mahdi Nazmul
# 16
# 17
# Mahdi
# 19
# Nazmul
# Mahdi
# 22
# 23
# Mahdi
# Nazmul
# 26
# Mahdi
# 28
# 29
# Mahdi Nazmul
# 31
# 32
# Mahdi
# 34
# Nazmul
# Mahdi
# 37
# 38
# Mahdi
# Nazmul
# 41
# Mahdi
# 43
# 44
# Mahdi Nazmul
# 46
# 47
# Mahdi
# 49
# Nazmul
# Mahdi
# 52
# 53
# Mahdi
# Nazmul
# 56
# Mahdi
# 58
# 59
# Mahdi Nazmul
# 61
# 62
# Mahdi
# 64
# Nazmul
# Mahdi
# 67
# 68
# Mahdi
# Nazmul
# 71
# Mahdi
# 73
# 74
# Mahdi Nazmul
# 76
# 77
# Mahdi
# 79
# Nazmul
# Mahdi
# 82
# 83
# Mahdi
# Nazmul
# 86
# Mahdi
# 88
# 89
# Mahdi Nazmul
# 91
# 92
# Mahdi
# 94
# Nazmul
# Mahdi
# 97
# 98
# Mahdi
# Nazmul
