# %%
i =1
num1=3
num2=5

while i<=100:
        
    if i%num1==0 and i%num2==0:
        print("Rahim Karim")
        
    elif i%num1==0 and i%num2 !=0:
        print("mahdi")
        
    elif i%num2==0 and i%num1 !=0:
        print("Nazmul")
        
    else:
        print(i)
        
        
    i+=1
# Out:
# 1
# 2
# mahdi
# 4
# Nazmul
# mahdi
# 7
# 8
# mahdi
# Nazmul
# 11
# mahdi
# 13
# 14
# Rahim Karim
# 16
# 17
# mahdi
# 19
# Nazmul
# mahdi
# 22
# 23
# mahdi
# Nazmul
# 26
# mahdi
# 28
# 29
# Rahim Karim
# 31
# 32
# mahdi
# 34
# Nazmul
# mahdi
# 37
# 38
# mahdi
# Nazmul
# 41
# mahdi
# 43
# 44
# Rahim Karim
# 46
# 47
# mahdi
# 49
# Nazmul
# mahdi
# 52
# 53
# mahdi
# Nazmul
# 56
# mahdi
# 58
# 59
# Rahim Karim
# 61
# 62
# mahdi
# 64
# Nazmul
# mahdi
# 67
# 68
# mahdi
# Nazmul
# 71
# mahdi
# 73
# 74
# Rahim Karim
# 76
# 77
# mahdi
# 79
# Nazmul
# mahdi
# 82
# 83
# mahdi
# Nazmul
# 86
# mahdi
# 88
# 89
# Rahim Karim
# 91
# 92
# mahdi
# 94
# Nazmul
# mahdi
# 97
# 98
# mahdi
# Nazmul
